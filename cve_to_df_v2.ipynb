# %%
import nvdlib
import pandas as pd
from datetime import datetime, timedelta

api_key = '1aac5d44-2d62-415e-92a8-ff2a6e251fc0'

# Define the time range (y, m, day)
end_date = datetime.today()
start_date = end_date - timedelta(days=120)

# We can only work with the cve's from 120 days ago till today (nvdlib limitations)

# %%
# Search for CVEs within the specified time range
cve_details = nvdlib.searchCVE(pubStartDate=start_date, pubEndDate=end_date, key=api_key)

print(len(cve_details))
# Out:
# 10639

# %%
alldata = []

for cve in cve_details:
    data = {
        'id': [cve.id],
        'sourceIdentifier': [cve.sourceIdentifier],
        'published': [cve.published],
        'lastModified': [cve.lastModified],
        'vulnStatus': [cve.vulnStatus],
        'cisaExploitAdd': [getattr(cve, 'cisaExploitAdd', None)],
        'cisaActionDue': [getattr(cve, 'cisaActionDue', None)],
        'cisaRequiredAction': [getattr(cve, 'cisaRequiredAction', None)],
        'cisaVulnerabilityName': [getattr(cve, 'cisaVulnerabilityName', None)],
        'v31score': [getattr(cve, 'v31score', None)],
        'v31vector': [getattr(cve, 'v31vector', None)],
        'v31severity': [getattr(cve, 'v31severity', None)],
        'v31attackVector': [getattr(cve, 'v31attackVector', None)],
        'v31attackComplexity': [getattr(cve, 'v31attackComplexity', None)],
        'v31privilegesRequired': [getattr(cve, 'v31privilegesRequired', None)],
        'v31userInteraction': [getattr(cve, 'v31userInteraction', None)],
        'v31scope': [getattr(cve, 'v31scope', None)],
        'v31confidentialityImpact': [getattr(cve, 'v31confidentialityImpact', None)],
        'v31integrityImpact': [getattr(cve, 'v31integrityImpact', None)],
        'v31availabilityImpact': [getattr(cve, 'v31availabilityImpact', None)],
        'v31exploitability': [getattr(cve, 'v31exploitability', None)],
        'v31impactScore': [getattr(cve, 'v31impactScore', None)],
        'v2score': [getattr(cve, 'v2score', None)],
        'v2vector': [getattr(cve, 'v2vector', None)],
        'v2severity': [getattr(cve, 'v2severity', None)],
        'v2accessVector': [getattr(cve, 'v2accessVector', None)],
        'v2accessComplexity': [getattr(cve, 'v2accessComplexity', None)],
        'v2authentication': [getattr(cve, 'v2authentication', None)],
        'v2confidentialityImpact': [getattr(cve, 'v2confidentialityImpact', None)],
        'v2integrityImpact': [getattr(cve, 'v2integrityImpact', None)],
        'v2availabilityImpact': [getattr(cve, 'v2availabilityImpact', None)],
        'v2exploitability': [getattr(cve, 'v2exploitability', None)],
        'v2impactScore': [getattr(cve, 'v2impactScore', None)],
        'score': [cve.score]
    }
    if data['score'][0][0]!=None: alldata.append(data)

df = pd.DataFrame(alldata)

# %%
df
# Out:
#                     id                  sourceIdentifier  \
# 0     [CVE-2023-42361]                   [cve@mitre.org]
# 1     [CVE-2023-46001]                   [cve@mitre.org]
# 2     [CVE-2023-46793]           [help@fluidattacks.com]
# 3     [CVE-2023-46800]           [help@fluidattacks.com]
# 4     [CVE-2023-43984]                   [cve@mitre.org]
# ...                ...                               ...
# 9284  [CVE-2023-48703]  [security-advisories@github.com]
# 9285  [CVE-2024-27307]  [security-advisories@github.com]
# 9286  [CVE-2024-27308]  [security-advisories@github.com]
# 9287  [CVE-2024-27915]  [security-advisories@github.com]
# 9288  [CVE-2024-27917]  [security-advisories@github.com]
#
#                       published               lastModified  \
# 0     [2023-11-07T22:15:11.167]  [2023-11-15T15:36:46.743]
# 1     [2023-11-07T22:15:11.473]  [2023-11-16T16:17:08.710]
# 2     [2023-11-07T22:15:12.280]  [2023-11-13T17:59:08.997]
# 3     [2023-11-07T22:15:14.037]  [2023-11-13T17:57:34.490]
# 4     [2023-11-07T23:15:07.680]  [2023-11-15T15:36:11.513]
# ...                         ...                        ...
# 9284  [2024-03-06T20:15:47.343]  [2024-03-06T21:42:48.053]
# 9285  [2024-03-06T20:15:47.537]  [2024-03-06T21:42:48.053]
# 9286  [2024-03-06T20:15:47.730]  [2024-03-06T21:42:48.053]
# 9287  [2024-03-06T20:15:47.930]  [2024-03-06T21:42:48.053]
# 9288  [2024-03-06T20:15:48.120]  [2024-03-06T21:42:48.053]
#
#                vulnStatus cisaExploitAdd cisaActionDue cisaRequiredAction  \
# 0              [Analyzed]         [None]        [None]             [None]
# 1              [Analyzed]         [None]        [None]             [None]
# 2              [Analyzed]         [None]        [None]             [None]
# 3              [Analyzed]         [None]        [None]             [None]
# 4              [Analyzed]         [None]        [None]             [None]
# ...                   ...            ...           ...                ...
# 9284  [Awaiting Analysis]         [None]        [None]             [None]
# 9285  [Awaiting Analysis]         [None]        [None]             [None]
# 9286  [Awaiting Analysis]         [None]        [None]             [None]
# 9287  [Awaiting Analysis]         [None]        [None]             [None]
# 9288  [Awaiting Analysis]         [None]        [None]             [None]
#
#      cisaVulnerabilityName v31score  ... v2severity v2accessVector  \
# 0                   [None]    [7.8]  ...     [None]         [None]
# 1                   [None]    [5.5]  ...     [None]         [None]
# 2                   [None]    [9.8]  ...     [None]         [None]
# 3                   [None]    [9.8]  ...     [None]         [None]
# 4                   [None]    [7.5]  ...     [None]         [None]
# ...                    ...      ...  ...        ...            ...
# 9284                [None]    [7.5]  ...     [None]         [None]
# 9285                [None]    [9.8]  ...     [None]         [None]
# 9286                [None]    [7.5]  ...     [None]         [None]
# 9287                [None]    [6.8]  ...     [None]         [None]
# 9288                [None]    [7.5]  ...     [None]         [None]
#
#      v2accessComplexity v2authentication v2confidentialityImpact  \
# 0                [None]           [None]                  [None]
# 1                [None]           [None]                  [None]
# 2                [None]           [None]                  [None]
# 3                [None]           [None]                  [None]
# 4                [None]           [None]                  [None]
# ...                 ...              ...                     ...
# 9284             [None]           [None]                  [None]
# 9285             [None]           [None]                  [None]
# 9286             [None]           [None]                  [None]
# 9287             [None]           [None]                  [None]
# 9288             [None]           [None]                  [None]
#
#      v2integrityImpact v2availabilityImpact v2exploitability v2impactScore  \
# 0               [None]               [None]           [None]        [None]
# 1               [None]               [None]           [None]        [None]
# 2               [None]               [None]           [None]        [None]
# 3               [None]               [None]           [None]        [None]
# 4               [None]               [None]           [None]        [None]
# ...                ...                  ...              ...           ...
# 9284            [None]               [None]           [None]        [None]
# 9285            [None]               [None]           [None]        [None]
# 9286            [None]               [None]           [None]        [None]
# 9287            [None]               [None]           [None]        [None]
# 9288            [None]               [None]           [None]        [None]
#
#                        score
# 0         [[V31, 7.8, HIGH]]
# 1       [[V31, 5.5, MEDIUM]]
# 2     [[V31, 9.8, CRITICAL]]
# 3     [[V31, 9.8, CRITICAL]]
# 4         [[V31, 7.5, HIGH]]
# ...                      ...
# 9284      [[V31, 7.5, HIGH]]
# 9285  [[V31, 9.8, CRITICAL]]
# 9286      [[V31, 7.5, HIGH]]
# 9287    [[V31, 6.8, MEDIUM]]
# 9288      [[V31, 7.5, HIGH]]
#
# [9289 rows x 34 columns]
